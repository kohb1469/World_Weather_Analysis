# %%
import requests
import sys
sys.path.append('C:/Users/Bryan/DataClass/World_Weather_Analysis')
from config import weather_api_key
import time
from datetime import datetime

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | sturgeon bay
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | beloha
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | culaman
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | aktau
# Processing Record 15 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 1 | vardo
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | carutapera
# Processing Record 21 of Set 1 | grand gaube
# Processing Record 22 of Set 1 | san patricio
# Processing Record 23 of Set 1 | matara
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | broken hill
# Processing Record 27 of Set 1 | miramar
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | phichit
# Processing Record 32 of Set 1 | perth
# Processing Record 33 of Set 1 | port shepstone
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | jati
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | bontang
# Processing Record 38 of Set 1 | maceio
# Processing Record 39 of Set 1 | tayga
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | xining
# Processing Record 42 of Set 1 | kamenka
# Processing Record 43 of Set 1 | nushki
# Processing Record 44 of Set 1 | rocha
# Processing Record 45 of Set 1 | sisimiut
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | ozernovskiy
# Processing Record 49 of Set 1 | conde
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | asfi
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 2 | lithakia
# Processing Record 6 of Set 2 | malmesbury
# Processing Record 7 of Set 2 | inhambane
# Processing Record 8 of Set 2 | ciampea
# Processing Record 9 of Set 2 | bucerias
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | mozarlandia
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | kralendijk
# Processing Record 15 of Set 2 | vestmannaeyjar
# Processing Record 16 of Set 2 | sivas
# Processing Record 17 of Set 2 | vitim
# Processing Record 18 of Set 2 | puerto del rosario
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | brae
# Processing Record 21 of Set 2 | camacha
# Processing Record 22 of Set 2 | poum
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | korla
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | wajima
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | sao filipe
# Processing Record 33 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 2 | lorengau
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 2 | maldonado
# Processing Record 39 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 2 | krasnyy chikoy
# Processing Record 41 of Set 2 | chapais
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | ostrovnoy
# Processing Record 1 of Set 3 | honolulu
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | solnechnyy
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | lucapa
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | codrington
# Processing Record 9 of Set 3 | isangel
# Processing Record 10 of Set 3 | mumford
# Processing Record 11 of Set 3 | beyneu
# Processing Record 12 of Set 3 | sorland
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | husavik
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 3 | harboore
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | kidal
# Processing Record 20 of Set 3 | coihaique
# Processing Record 21 of Set 3 | chor
# Processing Record 22 of Set 3 | pangnirtung
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | caravelas
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | taoudenni
# Processing Record 27 of Set 3 | ketchikan
# Processing Record 28 of Set 3 | dekernes
# Processing Record 29 of Set 3 | simbahan
# Processing Record 30 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | general roca
# Processing Record 33 of Set 3 | richards bay
# Processing Record 34 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 3 | paamiut
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | ambovombe
# Processing Record 38 of Set 3 | batemans bay
# Processing Record 39 of Set 3 | ayrum
# Processing Record 40 of Set 3 | qaqortoq
# Processing Record 41 of Set 3 | balabac
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | esperance
# Processing Record 44 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 3 | cartagena
# Processing Record 46 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 3 | wawa
# Processing Record 48 of Set 3 | yaan
# Processing Record 49 of Set 3 | insar
# Processing Record 50 of Set 3 | sayyan
# Processing Record 1 of Set 4 | san cristobal
# Processing Record 2 of Set 4 | moranbah
# Processing Record 3 of Set 4 | namatanai
# Processing Record 4 of Set 4 | kokoda
# Processing Record 5 of Set 4 | tasiilaq
# Processing Record 6 of Set 4 | nikolskoye
# Processing Record 7 of Set 4 | oistins
# Processing Record 8 of Set 4 | sinnai
# Processing Record 9 of Set 4 | zirgan
# Processing Record 10 of Set 4 | college
# Processing Record 11 of Set 4 | chutung
# City not found. Skipping...
# Processing Record 12 of Set 4 | itaituba
# Processing Record 13 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 4 | novyy urengoy
# Processing Record 15 of Set 4 | santa cruz cabralia
# Processing Record 16 of Set 4 | twin falls
# Processing Record 17 of Set 4 | burnie
# Processing Record 18 of Set 4 | wattegama
# Processing Record 19 of Set 4 | zhangye
# Processing Record 20 of Set 4 | bud
# Processing Record 21 of Set 4 | katobu
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | vagur
# Processing Record 24 of Set 4 | palmaner
# Processing Record 25 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 4 | roald
# Processing Record 27 of Set 4 | narsaq
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 4 | willowmore
# Processing Record 30 of Set 4 | kaka
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | velez-malaga
# Processing Record 34 of Set 4 | port moresby
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | havoysund
# Processing Record 37 of Set 4 | berlevag
# Processing Record 38 of Set 4 | alice springs
# Processing Record 39 of Set 4 | masvingo
# Processing Record 40 of Set 4 | luderitz
# Processing Record 41 of Set 4 | constitucion
# Processing Record 42 of Set 4 | hambantota
# Processing Record 43 of Set 4 | lam luk ka
# Processing Record 44 of Set 4 | lichinga
# Processing Record 45 of Set 4 | godo
# Processing Record 46 of Set 4 | beian
# Processing Record 47 of Set 4 | kiruna
# Processing Record 48 of Set 4 | bengkulu
# Processing Record 49 of Set 4 | zuenoula
# Processing Record 50 of Set 4 | henties bay
# Processing Record 1 of Set 5 | mnogovershinnyy
# Processing Record 2 of Set 5 | qaanaaq
# Processing Record 3 of Set 5 | hofn
# Processing Record 4 of Set 5 | zaysan
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | yuanping
# Processing Record 7 of Set 5 | victoria point
# Processing Record 8 of Set 5 | bereslavka
# Processing Record 9 of Set 5 | port augusta
# Processing Record 10 of Set 5 | aqtobe
# Processing Record 11 of Set 5 | makubetsu
# Processing Record 12 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 13 of Set 5 | fatezh
# Processing Record 14 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 5 | meadow lake
# Processing Record 16 of Set 5 | porto novo
# Processing Record 17 of Set 5 | omsukchan
# Processing Record 18 of Set 5 | bilibino
# Processing Record 19 of Set 5 | tomigusuku
# Processing Record 20 of Set 5 | baruun-urt
# Processing Record 21 of Set 5 | victoria
# Processing Record 22 of Set 5 | lakatoro
# Processing Record 23 of Set 5 | fort nelson
# Processing Record 24 of Set 5 | shimoda
# Processing Record 25 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | lufilufi
# Processing Record 28 of Set 5 | santa maria
# Processing Record 29 of Set 5 | port hardy
# Processing Record 30 of Set 5 | ferrol
# Processing Record 31 of Set 5 | ust-kulom
# Processing Record 32 of Set 5 | burica
# City not found. Skipping...
# Processing Record 33 of Set 5 | stornoway
# Processing Record 34 of Set 5 | goderich
# Processing Record 35 of Set 5 | olhao
# Processing Record 36 of Set 5 | cidreira
# Processing Record 37 of Set 5 | dillon
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | port arthur
# Processing Record 40 of Set 5 | molina
# Processing Record 41 of Set 5 | mersing
# Processing Record 42 of Set 5 | cukai
# Processing Record 43 of Set 5 | pine bluff
# Processing Record 44 of Set 5 | curaca
# Processing Record 45 of Set 5 | alashtar
# City not found. Skipping...
# Processing Record 46 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 5 | jaten
# Processing Record 48 of Set 5 | oussouye
# Processing Record 49 of Set 5 | ancud
# Processing Record 50 of Set 5 | de-kastri
# Processing Record 1 of Set 6 | hami
# Processing Record 2 of Set 6 | petlawad
# Processing Record 3 of Set 6 | channel-port aux basques
# Processing Record 4 of Set 6 | voljevac
# Processing Record 5 of Set 6 | vao
# Processing Record 6 of Set 6 | vangaindrano
# Processing Record 7 of Set 6 | nouadhibou
# Processing Record 8 of Set 6 | deputatskiy
# Processing Record 9 of Set 6 | zavetnoye
# Processing Record 10 of Set 6 | sao joao dos patos
# Processing Record 11 of Set 6 | haukipudas
# Processing Record 12 of Set 6 | yarmouth
# Processing Record 13 of Set 6 | manzanillo
# Processing Record 14 of Set 6 | vostok
# Processing Record 15 of Set 6 | road town
# Processing Record 16 of Set 6 | bardiyah
# Processing Record 17 of Set 6 | leshukonskoye
# Processing Record 18 of Set 6 | muros
# Processing Record 19 of Set 6 | chokurdakh
# Processing Record 20 of Set 6 | salalah
# Processing Record 21 of Set 6 | kaitangata
# Processing Record 22 of Set 6 | srednekolymsk
# Processing Record 23 of Set 6 | faya
# Processing Record 24 of Set 6 | chumikan
# Processing Record 25 of Set 6 | katherine
# Processing Record 26 of Set 6 | balaipungut
# Processing Record 27 of Set 6 | abashiri
# Processing Record 28 of Set 6 | marystown
# Processing Record 29 of Set 6 | bandarbeyla
# Processing Record 30 of Set 6 | sobolevo
# Processing Record 31 of Set 6 | povenets
# Processing Record 32 of Set 6 | nizip
# Processing Record 33 of Set 6 | alberton
# Processing Record 34 of Set 6 | miri
# Processing Record 35 of Set 6 | cape coast
# Processing Record 36 of Set 6 | karratha
# Processing Record 37 of Set 6 | muriwai beach
# Processing Record 38 of Set 6 | nara
# Processing Record 39 of Set 6 | baghdad
# Processing Record 40 of Set 6 | garowe
# Processing Record 41 of Set 6 | paita
# Processing Record 42 of Set 6 | peru
# Processing Record 43 of Set 6 | te anau
# Processing Record 44 of Set 6 | fecamp
# Processing Record 45 of Set 6 | saint anthony
# Processing Record 46 of Set 6 | port lincoln
# Processing Record 47 of Set 6 | bowen
# Processing Record 48 of Set 6 | limon
# Processing Record 49 of Set 6 | zavodouspenskoye
# Processing Record 50 of Set 6 | pondicherry
# Processing Record 1 of Set 7 | neuquen
# Processing Record 2 of Set 7 | peniche
# Processing Record 3 of Set 7 | sur
# Processing Record 4 of Set 7 | najran
# Processing Record 5 of Set 7 | waitati
# Processing Record 6 of Set 7 | ust-nera
# Processing Record 7 of Set 7 | ngunguru
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | mattru
# Processing Record 10 of Set 7 | eskil
# Processing Record 11 of Set 7 | hervey bay
# Processing Record 12 of Set 7 | souillac
# Processing Record 13 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 14 of Set 7 | kinkala
# Processing Record 15 of Set 7 | samarai
# Processing Record 16 of Set 7 | rio gallegos
# Processing Record 17 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 7 | mountmellick
# Processing Record 19 of Set 7 | pemba
# Processing Record 20 of Set 7 | pocoes
# Processing Record 21 of Set 7 | tabat
# Processing Record 22 of Set 7 | grindavik
# Processing Record 23 of Set 7 | valdosta
# Processing Record 24 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 7 | yertsevo
# Processing Record 26 of Set 7 | jinji
# Processing Record 27 of Set 7 | hamilton
# Processing Record 28 of Set 7 | rafaela
# Processing Record 29 of Set 7 | negara
# Processing Record 30 of Set 7 | port hedland
# Processing Record 31 of Set 7 | gangarampur
# Processing Record 32 of Set 7 | guacui
# Processing Record 33 of Set 7 | bambanglipuro
# Processing Record 34 of Set 7 | alamos
# Processing Record 35 of Set 7 | kolyshley
# Processing Record 36 of Set 7 | cabedelo
# Processing Record 37 of Set 7 | north bend
# Processing Record 38 of Set 7 | bocana de paiwas
# Processing Record 39 of Set 7 | sakakah
# Processing Record 40 of Set 7 | mocuba
# Processing Record 41 of Set 7 | herat
# Processing Record 42 of Set 7 | tabulbah
# City not found. Skipping...
# Processing Record 43 of Set 7 | margate
# Processing Record 44 of Set 7 | tupelo
# Processing Record 45 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 46 of Set 7 | lompoc
# Processing Record 47 of Set 7 | avera
# Processing Record 48 of Set 7 | balkanabat
# Processing Record 49 of Set 7 | sechura
# Processing Record 50 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 1 of Set 8 | opportunity
# Processing Record 2 of Set 8 | hualmay
# Processing Record 3 of Set 8 | kavaratti
# Processing Record 4 of Set 8 | aykhal
# Processing Record 5 of Set 8 | high level
# Processing Record 6 of Set 8 | altay
# Processing Record 7 of Set 8 | russell
# Processing Record 8 of Set 8 | novo cruzeiro
# Processing Record 9 of Set 8 | puerto escondido
# Processing Record 10 of Set 8 | dikson
# Processing Record 11 of Set 8 | suntar
# Processing Record 12 of Set 8 | sola
# Processing Record 13 of Set 8 | faanui
# Processing Record 14 of Set 8 | emerald
# Processing Record 15 of Set 8 | salsomaggiore terme
# Processing Record 16 of Set 8 | talnakh
# Processing Record 17 of Set 8 | ilulissat
# Processing Record 18 of Set 8 | kang
# Processing Record 19 of Set 8 | templin
# Processing Record 20 of Set 8 | yeppoon
# Processing Record 21 of Set 8 | musoma
# Processing Record 22 of Set 8 | nanortalik
# Processing Record 23 of Set 8 | vila franca do campo
# Processing Record 24 of Set 8 | kapchorwa
# Processing Record 25 of Set 8 | bathsheba
# Processing Record 26 of Set 8 | terrace
# Processing Record 27 of Set 8 | itarema
# Processing Record 28 of Set 8 | saint george
# Processing Record 29 of Set 8 | key west
# Processing Record 30 of Set 8 | jaumave
# Processing Record 31 of Set 8 | pochutla
# Processing Record 32 of Set 8 | kimberley
# Processing Record 33 of Set 8 | olafsvik
# Processing Record 34 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 8 | aklavik
# Processing Record 36 of Set 8 | kaeo
# Processing Record 37 of Set 8 | meybod
# Processing Record 38 of Set 8 | severo-kurilsk
# Processing Record 39 of Set 8 | bilma
# Processing Record 40 of Set 8 | wau
# Processing Record 41 of Set 8 | mae ramat
# Processing Record 42 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 43 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 8 | chara
# Processing Record 45 of Set 8 | lagunas
# Processing Record 46 of Set 8 | leningradskiy
# Processing Record 47 of Set 8 | dukat
# Processing Record 48 of Set 8 | norman wells
# Processing Record 49 of Set 8 | bartica
# Processing Record 50 of Set 8 | thinadhoo
# Processing Record 1 of Set 9 | kimbe
# Processing Record 2 of Set 9 | mehamn
# Processing Record 3 of Set 9 | christchurch
# Processing Record 4 of Set 9 | west fargo
# Processing Record 5 of Set 9 | maamba
# Processing Record 6 of Set 9 | canora
# Processing Record 7 of Set 9 | minab
# Processing Record 8 of Set 9 | lavrentiya
# Processing Record 9 of Set 9 | vidra
# Processing Record 10 of Set 9 | tuatapere
# Processing Record 11 of Set 9 | anadyr
# Processing Record 12 of Set 9 | isla vista
# Processing Record 13 of Set 9 | pisco
# Processing Record 14 of Set 9 | palafrugell
# Processing Record 15 of Set 9 | aksu
# Processing Record 16 of Set 9 | harper
# Processing Record 17 of Set 9 | zhigansk
# Processing Record 18 of Set 9 | sarlat-la-caneda
# Processing Record 19 of Set 9 | jalu
# Processing Record 20 of Set 9 | valdivia
# Processing Record 21 of Set 9 | katangli
# Processing Record 22 of Set 9 | erdenet
# Processing Record 23 of Set 9 | sibolga
# Processing Record 24 of Set 9 | inuvik
# Processing Record 25 of Set 9 | antofagasta
# Processing Record 26 of Set 9 | nalgonda
# Processing Record 27 of Set 9 | san jose
# Processing Record 28 of Set 9 | auki
# Processing Record 29 of Set 9 | redmond
# Processing Record 30 of Set 9 | belgrade
# Processing Record 31 of Set 9 | dudinka
# Processing Record 32 of Set 9 | hornepayne
# Processing Record 33 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 9 | mullingar
# Processing Record 35 of Set 9 | natal
# Processing Record 36 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 9 | fairbanks
# Processing Record 38 of Set 9 | puri
# Processing Record 39 of Set 9 | mount isa
# Processing Record 40 of Set 9 | belmonte
# Processing Record 41 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 9 | broome
# Processing Record 43 of Set 9 | linfen
# Processing Record 44 of Set 9 | rawson
# Processing Record 45 of Set 9 | natitingou
# Processing Record 46 of Set 9 | flinders
# Processing Record 47 of Set 9 | medzev
# Processing Record 48 of Set 9 | espoo
# Processing Record 49 of Set 9 | yvetot
# Processing Record 50 of Set 9 | nsanje
# Processing Record 1 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 10 | kashi
# Processing Record 3 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 10 | gueret
# Processing Record 5 of Set 10 | pokhara
# Processing Record 6 of Set 10 | vanimo
# Processing Record 7 of Set 10 | kloulklubed
# Processing Record 8 of Set 10 | yarim
# Processing Record 9 of Set 10 | kuito
# Processing Record 10 of Set 10 | kalia
# Processing Record 11 of Set 10 | sinnamary
# Processing Record 12 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 10 | ambon
# Processing Record 14 of Set 10 | acapulco
# Processing Record 15 of Set 10 | huarmey
# Processing Record 16 of Set 10 | goundam
# Processing Record 17 of Set 10 | milkovo
# Processing Record 18 of Set 10 | chamalieres
# Processing Record 19 of Set 10 | sitka
# Processing Record 20 of Set 10 | baiyin
# Processing Record 21 of Set 10 | ankang
# Processing Record 22 of Set 10 | havre-saint-pierre
# Processing Record 23 of Set 10 | hovd
# Processing Record 24 of Set 10 | verkhnevilyuysk
# Processing Record 25 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 26 of Set 10 | ilam
# Processing Record 27 of Set 10 | greenwood
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | bonthe
# Processing Record 30 of Set 10 | floriano
# Processing Record 31 of Set 10 | ngaoundere
# Processing Record 32 of Set 10 | chaupimarca
# Processing Record 33 of Set 10 | hanmer springs
# Processing Record 34 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 35 of Set 10 | vredendal
# Processing Record 36 of Set 10 | alofi
# Processing Record 37 of Set 10 | longyearbyen
# Processing Record 38 of Set 10 | la massana
# Processing Record 39 of Set 10 | miandrivazo
# Processing Record 40 of Set 10 | itoman
# Processing Record 41 of Set 10 | kalmunai
# Processing Record 42 of Set 10 | belyy yar
# Processing Record 43 of Set 10 | bairiki
# Processing Record 44 of Set 10 | stephenville
# Processing Record 45 of Set 10 | krasnoselkup
# Processing Record 46 of Set 10 | cilegon
# Processing Record 47 of Set 10 | rio grande
# Processing Record 48 of Set 10 | komsomolskiy
# Processing Record 49 of Set 10 | ixtapa
# Processing Record 50 of Set 10 | hay river
# Processing Record 1 of Set 11 | riyadh
# Processing Record 2 of Set 11 | jinchang
# Processing Record 3 of Set 11 | ponta delgada
# Processing Record 4 of Set 11 | fort-shevchenko
# Processing Record 5 of Set 11 | lander
# Processing Record 6 of Set 11 | portland
# Processing Record 7 of Set 11 | saryozek
# Processing Record 8 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 9 of Set 11 | cleveland
# Processing Record 10 of Set 11 | khandbari
# Processing Record 11 of Set 11 | seydi
# Processing Record 12 of Set 11 | panguna
# Processing Record 13 of Set 11 | lishu
# Processing Record 14 of Set 11 | muli
# Processing Record 15 of Set 11 | arkhangelsk
# Processing Record 16 of Set 11 | babu
# Processing Record 17 of Set 11 | ishigaki
# Processing Record 18 of Set 11 | samfya
# Processing Record 19 of Set 11 | nioro
# Processing Record 20 of Set 11 | jiayuguan
# Processing Record 21 of Set 11 | douentza
# Processing Record 22 of Set 11 | kosjeric
# Processing Record 23 of Set 11 | urumqi
# Processing Record 24 of Set 11 | jesus
# Processing Record 25 of Set 11 | la ronge
# Processing Record 26 of Set 11 | meggen
# Processing Record 27 of Set 11 | sao gabriel da cachoeira
# Processing Record 28 of Set 11 | dumra
# Processing Record 29 of Set 11 | fougamou
# Processing Record 30 of Set 11 | ubaitaba
# Processing Record 31 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 11 | sao joao da barra
# Processing Record 33 of Set 11 | ustka
# Processing Record 34 of Set 11 | gizo
# Processing Record 35 of Set 11 | pangkalanbuun
# Processing Record 36 of Set 11 | taltal
# Processing Record 37 of Set 11 | florianopolis
# Processing Record 38 of Set 11 | miyako
# Processing Record 39 of Set 11 | piranhas
# Processing Record 40 of Set 11 | sim
# Processing Record 41 of Set 11 | marihatag
# Processing Record 42 of Set 11 | abay
# Processing Record 43 of Set 11 | muswellbrook
# Processing Record 44 of Set 11 | mbalmayo
# Processing Record 45 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 46 of Set 11 | lata
# Processing Record 47 of Set 11 | halifax
# Processing Record 48 of Set 11 | ibarra
# Processing Record 49 of Set 11 | yar-sale
# Processing Record 50 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 12 | kijang
# Processing Record 2 of Set 12 | hobyo
# Processing Record 3 of Set 12 | jilib
# Processing Record 4 of Set 12 | mount gambier
# Processing Record 5 of Set 12 | dagana
# Processing Record 6 of Set 12 | kirkwood
# Processing Record 7 of Set 12 | benguela
# Processing Record 8 of Set 12 | sharjah
# Processing Record 9 of Set 12 | akyab
# Processing Record 10 of Set 12 | aswan
# Processing Record 11 of Set 12 | kawalu
# Processing Record 12 of Set 12 | coahuayana
# Processing Record 13 of Set 12 | okitipupa
# Processing Record 14 of Set 12 | kedgwick
# Processing Record 15 of Set 12 | graaff-reinet
# Processing Record 16 of Set 12 | buala
# Processing Record 17 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 12 | bollnas
# Processing Record 20 of Set 12 | majene
# Processing Record 21 of Set 12 | umm kaddadah
# Processing Record 22 of Set 12 | muri
# Processing Record 23 of Set 12 | kez
# Processing Record 24 of Set 12 | darab
# Processing Record 25 of Set 12 | vestmanna
# Processing Record 26 of Set 12 | quatre cocos
# Processing Record 27 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 28 of Set 12 | karoi
# Processing Record 29 of Set 12 | tefe
# Processing Record 30 of Set 12 | signagi
# City not found. Skipping...
# Processing Record 31 of Set 12 | vidor
# Processing Record 32 of Set 12 | port hawkesbury
# Processing Record 33 of Set 12 | santa vitoria do palmar
# Processing Record 34 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 12 | agadez
# Processing Record 36 of Set 12 | taian
# Processing Record 37 of Set 12 | nemuro
# Processing Record 38 of Set 12 | tabou
# Processing Record 39 of Set 12 | lasa
# Processing Record 40 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 12 | morant bay
# Processing Record 42 of Set 12 | tanhacu
# Processing Record 43 of Set 12 | lambari
# Processing Record 44 of Set 12 | felipe carrillo puerto
# Processing Record 45 of Set 12 | kahului
# Processing Record 46 of Set 12 | tokur
# Processing Record 47 of Set 12 | waipawa
# Processing Record 48 of Set 12 | along
# Processing Record 49 of Set 12 | kabompo
# Processing Record 50 of Set 12 | klaksvik
# Processing Record 1 of Set 13 | yulara
# Processing Record 2 of Set 13 | mirnyy
# Processing Record 3 of Set 13 | kenai
# Processing Record 4 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 13 | cradock
# Processing Record 6 of Set 13 | foumbot
# Processing Record 7 of Set 13 | ambilobe
# Processing Record 8 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 9 of Set 13 | nizhneangarsk
# Processing Record 10 of Set 13 | chany
# Processing Record 11 of Set 13 | wanning
# Processing Record 12 of Set 13 | turukhansk
# Processing Record 13 of Set 13 | helong
# Processing Record 14 of Set 13 | agirish
# Processing Record 15 of Set 13 | santa barbara
# Processing Record 16 of Set 13 | alcudia
# Processing Record 17 of Set 13 | les cayes
# Processing Record 18 of Set 13 | gourcy
# Processing Record 19 of Set 13 | psebay
# Processing Record 20 of Set 13 | ruteng
# Processing Record 21 of Set 13 | vidalia
# Processing Record 22 of Set 13 | ornskoldsvik
# Processing Record 23 of Set 13 | kamyshin
# Processing Record 24 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 13 | luba
# Processing Record 26 of Set 13 | balykshi
# Processing Record 27 of Set 13 | hirara
# Processing Record 28 of Set 13 | coesfeld
# Processing Record 29 of Set 13 | farafangana
# Processing Record 30 of Set 13 | kavos
# Processing Record 31 of Set 13 | muravlenko
# Processing Record 32 of Set 13 | nishihara
# Processing Record 33 of Set 13 | hwange
# Processing Record 34 of Set 13 | presidencia roque saenz pena
# Processing Record 35 of Set 13 | laguna
# Processing Record 36 of Set 13 | mandalgovi
# Processing Record 37 of Set 13 | dum duma
# Processing Record 38 of Set 13 | okakarara
# Processing Record 39 of Set 13 | mercedes
# Processing Record 40 of Set 13 | skhisma
# Processing Record 41 of Set 13 | caborca
# Processing Record 42 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 43 of Set 13 | raahe
# Processing Record 44 of Set 13 | dire dawa
# Processing Record 45 of Set 13 | lakes entrance
# Processing Record 46 of Set 13 | tigao
# Processing Record 47 of Set 13 | kangaatsiaq
# Processing Record 48 of Set 13 | ndouci
# City not found. Skipping...
# Processing Record 49 of Set 13 | jumla
# Processing Record 50 of Set 13 | travesia
# Processing Record 1 of Set 14 | chibombo
# Processing Record 2 of Set 14 | panaba
# Processing Record 3 of Set 14 | ca mau
# Processing Record 4 of Set 14 | kanniyakumari
# Processing Record 5 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 6 of Set 14 | coquimbo
# Processing Record 7 of Set 14 | dalbandin
# Processing Record 8 of Set 14 | kayerkan
# Processing Record 9 of Set 14 | bonavista
# Processing Record 10 of Set 14 | borogontsy
# Processing Record 11 of Set 14 | los llanos de aridane
# Processing Record 12 of Set 14 | kavieng
# Processing Record 13 of Set 14 | namie
# Processing Record 14 of Set 14 | casino
# Processing Record 15 of Set 14 | voi
# Processing Record 16 of Set 14 | amazar
# Processing Record 17 of Set 14 | eyl
# Processing Record 18 of Set 14 | tura
# Processing Record 19 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 20 of Set 14 | niltepec
# Processing Record 21 of Set 14 | rincon
# Processing Record 22 of Set 14 | izumo
# Processing Record 23 of Set 14 | biak
# Processing Record 24 of Set 14 | walvis bay
# Processing Record 25 of Set 14 | lumberton
# Processing Record 26 of Set 14 | la uribe
# City not found. Skipping...
# Processing Record 27 of Set 14 | qingdao
# Processing Record 28 of Set 14 | cromwell
# Processing Record 29 of Set 14 | mantua
# Processing Record 30 of Set 14 | fuzhou
# Processing Record 31 of Set 14 | kpalime
# Processing Record 32 of Set 14 | vichy
# Processing Record 33 of Set 14 | bayan
# Processing Record 34 of Set 14 | farah
# Processing Record 35 of Set 14 | moussoro
# Processing Record 36 of Set 14 | lesnoy
# Processing Record 37 of Set 14 | marstal
# Processing Record 38 of Set 14 | mancio lima
# Processing Record 39 of Set 14 | gonen
# Processing Record 40 of Set 14 | guanica
# Processing Record 41 of Set 14 | leh
# Processing Record 42 of Set 14 | cockburn town
# Processing Record 43 of Set 14 | almaznyy
# Processing Record 44 of Set 14 | havelock
# Processing Record 45 of Set 14 | ouallam
# Processing Record 46 of Set 14 | mahon
# Processing Record 47 of Set 14 | jardim
# Processing Record 48 of Set 14 | dongsheng
# Processing Record 49 of Set 14 | kajaani
# Processing Record 50 of Set 14 | timra
# Processing Record 1 of Set 15 | naze
# Processing Record 2 of Set 15 | finschhafen
# Processing Record 3 of Set 15 | suez
# Processing Record 4 of Set 15 | xian
# Processing Record 5 of Set 15 | seoul
# Processing Record 6 of Set 15 | manokwari
# Processing Record 7 of Set 15 | abha
# Processing Record 8 of Set 15 | manga
# Processing Record 9 of Set 15 | tanshui
# City not found. Skipping...
# Processing Record 10 of Set 15 | saint-augustin
# Processing Record 11 of Set 15 | staroaleyskoye
# Processing Record 12 of Set 15 | karpathos
# Processing Record 13 of Set 15 | okhotsk
# Processing Record 14 of Set 15 | cangas
# Processing Record 15 of Set 15 | petauke
# Processing Record 16 of Set 15 | winslow
# Processing Record 17 of Set 15 | greensboro
# Processing Record 18 of Set 15 | santo domingo
# Processing Record 19 of Set 15 | padang
# Processing Record 20 of Set 15 | pujili
# Processing Record 21 of Set 15 | acari
# Processing Record 22 of Set 15 | medicine hat
# Processing Record 23 of Set 15 | onega
# Processing Record 24 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 25 of Set 15 | sao miguel do araguaia
# Processing Record 26 of Set 15 | ruiru
# Processing Record 27 of Set 15 | micheweni
# Processing Record 28 of Set 15 | ivoti
# Processing Record 29 of Set 15 | kincardine
# Processing Record 30 of Set 15 | darapidap
# Processing Record 31 of Set 15 | dafeng
# Processing Record 32 of Set 15 | paraiso
# Processing Record 33 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 34 of Set 15 | san policarpo
# Processing Record 35 of Set 15 | lezajsk
# Processing Record 36 of Set 15 | saint-pierre
# Processing Record 37 of Set 15 | san quintin
# Processing Record 38 of Set 15 | chinsali
# Processing Record 39 of Set 15 | abohar
# Processing Record 40 of Set 15 | thunder bay
# Processing Record 41 of Set 15 | ahipara
# Processing Record 42 of Set 15 | chicama
# Processing Record 43 of Set 15 | morro bay
# Processing Record 44 of Set 15 | sal rei
# Processing Record 45 of Set 15 | soma
# Processing Record 46 of Set 15 | pontianak
# Processing Record 47 of Set 15 | kuching
# Processing Record 48 of Set 15 | boa vista
# Processing Record 49 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 50 of Set 15 | lensk
# Processing Record 1 of Set 16 | gat
# Processing Record 2 of Set 16 | beringovskiy
# Processing Record 3 of Set 16 | abu samrah
# Processing Record 4 of Set 16 | san andres
# Processing Record 5 of Set 16 | ahuimanu
# Processing Record 6 of Set 16 | rundu
# Processing Record 7 of Set 16 | kaitong
# Processing Record 8 of Set 16 | tres arroyos
# Processing Record 9 of Set 16 | salinopolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Barrow      US  71.2906 -156.7887     56.25        61          88
# 1           Tiksi      RU  71.6872  128.8694     45.88        69          92
# 2    Sturgeon Bay      US  44.8342  -87.3770     78.76        60          20
# 3      Georgetown      MY   5.4112  100.3354     80.89        90          20
# 4       Hithadhoo      MV  -0.6000   73.0833     81.50        68         100
# 5          Beloha      MG -25.1667   45.0500     69.89        63          76
# 6  Ribeira Grande      PT  38.5167  -28.7000     75.60        94          75
# 7          Bethel      US  41.3712  -73.4140     97.05        54          10
# 8         Culaman      PH   5.9603  125.6586     79.90        78         100
# 9       Carnarvon      AU -24.8667  113.6333     60.69        57          58
#
#    Wind Speed Current Description
# 0       17.16     overcast clouds
# 1        1.25     overcast clouds
# 2        9.22          few clouds
# 3        0.00          few clouds
# 4       11.21     overcast clouds
# 5        5.08       broken clouds
# 6        2.30       broken clouds
# 7        3.00           clear sky
# 8        2.30     overcast clouds
# 9       15.17       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
